# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time

# %%
suic = pd.read_csv("../merge/suic_new/Suic_Medio_Derhab_tasasporsexo.csv")
suic = suic.fillna(0)
ecnomi = pd.read_csv("../merge/suic_new/Variables Macroeconomicas.csv")
ecnomi
# Out:
#       cve_ent_mun gm_2020_a    rel_h_m  prom_hnv  graproes  propsinss  \
# 0            1001  Muy bajo  94.900002      1.98     10.84  18.250877
# 1            1002  Muy bajo  96.139999      2.62      8.54  14.727569
# 2            1003  Muy bajo  96.209999      2.67      8.05  20.312447
# 3            1004  Muy bajo  95.220001      2.51      9.08  13.805882
# 4            1005  Muy bajo  97.730003      2.11     10.22  21.010706
# ...           ...       ...        ...       ...       ...        ...
# 2460        32054      Bajo  95.589996      2.91      8.02  15.473619
# 2461        32055  Muy bajo  97.629997      2.81      8.08  25.163191
# 2462        32056  Muy bajo  92.709999      1.95     11.57  16.944395
# 2463        32057  Muy bajo  96.379997      2.53      8.61  13.840137
# 2464        32058      Bajo  95.269997      3.04      8.00  14.853632
#
#          propea  propdesoc   propocup  propdisc  ...  prop_alim_20  \
# ...

# %%
startTime = time.time()
result = suic.merge(ecnomi, how="inner", left_on=["cve_ent_mun"], right_on=["cve_ent_mun"])
endTime = time.time()
service = endTime-startTime
print(service)
# Out:
# 0.025705814361572266

# %%
anios_suc = suic.anio.unique()

# %%
df_sex = suic.groupby("sexo")
print(df_sex.indices)
# Out:
# {'Hombre': array([    0,     3,     6, ..., 51822, 51826, 51830]), 'Mujer': array([    1,     4,     7, ..., 51823, 51827, 51831]), 'NE/NA': array([  443,  1064,  5616,  6154,  6270,  6595,  6901,  8819, 10826,
#        16142, 18215, 22691, 25672, 28543, 29130, 30251, 39774, 41573,
#        42318, 42668, 51817, 51821, 51825, 51829]), 'Total': array([    2,     5,     8, ..., 51824, 51828, 51832])}

# %%
df_hombres = df_sex.get_group("Hombre")
df_hombres
# Out:
#          sexo  anio  cve_ent_mun  suicAhogamiento  suicAhorcamiento  \
# 0      Hombre  2000         1001                0                14
# 3      Hombre  2001         1001                0                30
# 6      Hombre  2002         1001                0                18
# 9      Hombre  2003         1001                0                24
# 12     Hombre  2004         1001                0                29
# ...       ...   ...          ...              ...               ...
# 51814  Hombre  2016          999                0                13
# 51818  Hombre  2017          999                1                56
# 51822  Hombre  2018          999                0               198
# 51826  Hombre  2019          999                0               116
# 51830  Hombre  2020          999                0               115
#
#        suicArma_fuego  suicEnvenenamiento  suicOtro  suicderhabNE  \
# 0                   4                   0         1           2.0
# ...

# %%
anios_suc = suic.anio.unique()
df_hombres_temp = df_hombres.groupby("anio")
df_hombres_temp

# %%
x=2000
passw=1
anios = []
while (x<2021):
    # print(x)
    anios.append(x)
    x = x+passw
anios
# Out:
# [2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020]

# %%
sumaa=0
for ano in anios:
    startTime = time.time()
    df_anio = df_hombres_temp.get_group(ano)
    result = df_anio.merge(ecnomi, how="inner", left_on=["cve_ent_mun"], right_on=["cve_ent_mun"])
    endTime = time.time()
    service = endTime-startTime
    sumaa = sumaa + service
    print("\tAnio = {} / Seg = {}".format(ano,service))
print("TOTAL = {} ".format(sumaa))
# Out:
# 	Anio = 2000 / Seg = 0.008363962173461914
# 	Anio = 2001 / Seg = 0.0046536922454833984
# 	Anio = 2002 / Seg = 0.005033731460571289
# 	Anio = 2003 / Seg = 0.004012346267700195
# 	Anio = 2004 / Seg = 0.003153085708618164
# 	Anio = 2005 / Seg = 0.003274679183959961
# 	Anio = 2006 / Seg = 0.004933834075927734
# 	Anio = 2007 / Seg = 0.005078554153442383
# 	Anio = 2008 / Seg = 0.0051708221435546875
# 	Anio = 2009 / Seg = 0.005034208297729492
# 	Anio = 2010 / Seg = 0.007493495941162109
# 	Anio = 2011 / Seg = 0.0035872459411621094
# 	Anio = 2012 / Seg = 0.003393888473510742
# 	Anio = 2013 / Seg = 0.003921031951904297
# 	Anio = 2014 / Seg = 0.0045626163482666016
# 	Anio = 2015 / Seg = 0.00398707389831543
# 	Anio = 2016 / Seg = 0.004322528839111328
# 	Anio = 2017 / Seg = 0.006235361099243164
# 	Anio = 2018 / Seg = 0.005148172378540039
# 	Anio = 2019 / Seg = 0.0037314891815185547
# 	Anio = 2020 / Seg = 0.0058591365814208984
# TOTAL = 0.10095095634460449

# %%
df_data = {"Test No.": ["S.O.",1,2,3,4,5,6],
     "Services Time - loadBalancer Sex": [0,1.14,1.32,1.38,1.43,1.45,1.48],
     "Services Time - loadBalancer Temporal": [0,1.01,1.05,1.14,1.25,1.31,1.36],
     "Services Time - Data Fusion": [0.15,0.15,0.125,0.046,0.036,0.032,0.027],
     "Services Time - Correlation": [37.77,37.77, 18.72, 9.78, 6.02, 4.89, 4.108]}

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.set(font_scale = 1.5)
sns.barplot(x="Test No.",y="Services Time - loadBalancer Sex", data=df_data, linewidth=2, saturation=4)
ax.bar_label(ax.containers[0])
plt.ylabel("Services Time - loadBalancer Sex \n Secons")
plt.xlabel("Test No.")
plt.title("SERVICE TIME - Sex")
# Out:
# Text(0.5, 1.0, 'SERVICE TIME - Sex')

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.set(font_scale = 1.5)
sns.barplot(x="Test No.",y="Services Time - loadBalancer Temporal", data=df_data, linewidth=2, saturation=4)
ax.bar_label(ax.containers[0])
plt.ylabel("Services Time - loadBalancer Temporal \n Secons")
plt.xlabel("Test No.")
plt.title("SERVICE TIME - Temporal")
# Out:
# Text(0.5, 1.0, 'SERVICE TIME - Temporal')

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.set(font_scale = 1.5)
sns.barplot(x="Test No.",y="Services Time - Data Fusion", data=df_data, linewidth=2, saturation=4)
ax.bar_label(ax.containers[0])
plt.ylabel("Services Time - loadBalancer Data Fusion \n Secons")
plt.xlabel("Test No.")
plt.title("SERVICE TIME - Data Fusion")
# Out:
# Text(0.5, 1.0, 'SERVICE TIME - Data Fusion')

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.set(font_scale = 1.5)
sns.barplot(x="Test No.",y="Services Time - Correlation", data=df_data, linewidth=2, saturation=4)
ax.bar_label(ax.containers[0])
plt.ylabel("Services Time - loadBalancer Correlation \n Secons")
plt.xlabel("Test No.")
plt.title("SERVICE TIME - Correlation")
# Out:
# Text(0.5, 1.0, 'SERVICE TIME - Correlation')

# %%
df_d = pd.DataFrame(df_data)
df_d
# Out:
#   Test No.  Services Time - loadBalancer Sex  \
# 0     S.O.                              0.00
# 1        1                              1.14
# 2        2                              1.32
# 3        3                              1.38
# 4        4                              1.43
# 5        5                              1.45
# 6        6                              1.48
#
#    Services Time - loadBalancer Temporal  Services Time - Data Fusion  \
# 0                                   0.00                        0.150
# 1                                   1.01                        0.150
# 2                                   1.05                        0.125
# 3                                   1.14                        0.046
# 4                                   1.25                        0.036
# 5                                   1.31                        0.032
# 6                                   1.36                        0.027
#
#    Services Time - Correlation
# ...

# %%
df_d.set_index("Test No.")
sumDF = df_d.sum(axis=1)
# Out:
# /tmp/ipykernel_78655/514256005.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sumDF = df_d.sum(axis=1)
# [37.92,
#  40.07,
#  21.215,
#  12.345999999999998,
#  8.735999999999999,
#  7.6819999999999995,
#  6.975]

# %%
df_2019 = {"Test": ["S.O.","Specific File"],
     "Service Time": [37.920, (1.035+0.083)]}
df_2019 = pd.DataFrame(data=df_2019)
df_2019
# Out:
#             Test  Service Time
# 0           S.O.        37.920
# 1  Specific File         1.118

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.set(font_scale = 1.5)
sns.barplot(x="Test",y="Service Time", data=df_2019, linewidth=2, saturation=4)
ax.bar_label(ax.containers[0])
plt.ylabel("Services Time - Specific File \n Secons")
plt.xlabel("Test")
plt.title("SERVICE TIME - S.O. vs Specific File")
# Out:
# Text(0.5, 1.0, 'SERVICE TIME - S.O. vs Specific File')
