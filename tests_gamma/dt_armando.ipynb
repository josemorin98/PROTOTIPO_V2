# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = {"Cant. workers (Test)": ["pandas",1,2,3,4,5],
     "Services Time - loadBalancer": [271,455,458,462,463,465],
     "Services Time - workers":[133,117.23, 63.56, 35.64, 25.38, 19.32]}
df
# Out:
# {'Cant. workers (Test)': ['pandas', 1, 2, 3, 4, 5],
#  'Services Time - loadBalancer': [271, 455, 458, 462, 463, 465],
#  'Services Time - workers': [133, 117.23, 63.56, 35.64, 25.38, 19.32]}

# %%
df_data = pd.DataFrame(data=df)
df_data
# Out:
#   Cant. workers (Test)  Services Time - loadBalancer  Services Time - workers
# 0               pandas                           271                   133.00
# 1                    1                           455                   117.23
# 2                    2                           458                    63.56
# 3                    3                           462                    35.64
# 4                    4                           463                    25.38
# 5                    5                           465                    19.32

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.barplot(x="Cant. workers (Test)",y="Services Time - workers", data=df_data, linewidth=2, saturation=4)
plt.title("SERVICE TIME - Cant. workers", fontsize = 20)
# Out:
# Text(0.5, 1.0, 'SERVICE TIME - Cant. workers')

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax = sns.barplot(x="Cant. workers (Test)",y="Services Time - loadBalancer", data=df_data, linewidth=2, saturation=4)
ax.bar_label(ax.containers[0])
#plt.plot(df_data["Cant. workers (Test)"], df_data["Services Time - loadBalancer"], c="k")
plt.title("SERVICE TIME - LoadBalancer", fontsize = 20)
# Out:
# Text(0.5, 1.0, 'SERVICE TIME - LoadBalancer')

# %%
df_data["Total Service Time"] = df_data["Services Time - workers"] + df_data["Services Time - loadBalancer"]
df_data
# Out:
#   Cant. workers (Test)  Services Time - loadBalancer  Services Time - workers  \
# 0               pandas                           271                   133.00
# 1                    1                           455                   117.23
# 2                    2                           458                    63.56
# 3                    3                           462                    35.64
# 4                    4                           463                    25.38
# 5                    5                           465                    19.32
#
#    Total Service Time
# 0              404.00
# 1              572.23
# 2              521.56
# 3              497.64
# 4              488.38
# 5              484.32

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.barplot(x="Cant. workers (Test)",y="Total Service Time", data=df_data, linewidth=2, saturation=4)
ax.bar_label(ax.containers[0])
plt.title("SERVICE TIME - Total", fontsize = 20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_62544/1814994706.py in <module>
#       1 fig, ax = plt.subplots(figsize=(10, 10))
# ----> 2 sns.barplot(x="Cant. workers (Test)",y="Total Service Time", data=df_data, linewidth=2, saturation=4)
#       3 ax.bar_label(ax.containers[0])
#       4 plt.title("SERVICE TIME - Total", fontsize = 20)
#
# ~/.local/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/.local/lib/python3.8/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
#
# ~/.local/lib/python3.8/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# ~/.local/lib/python3.8/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'Total Service Time'

# %%
df_2019 = {"Test": ["All file","Only date"],
     "Read Time": [131.67, 25.5],
     "Conteo Time":[6.6,1.3]}
df_2019 = pd.DataFrame(data=df_2019)
df_2019
# Out:
#         Test  Read Time  Conteo Time
# 0   All file     131.67          6.6
# 1  Only date      25.50          1.3

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.barplot(y="Read Time",x="Test", data=df_2019, linewidth=2, saturation=4)
plt.title("READ TIME - 2019", fontsize = 20)
plt.ylabel("Time (s)")
# Out:
# Text(0, 0.5, 'Time (s)')

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.barplot(y="Conteo Time",x="Test", data=df_2019, linewidth=2, saturation=4)
plt.title("COUNT TIME - 2019", fontsize = 20)
plt.ylabel("Time (s)")
# Out:
# Text(0, 0.5, 'Time (s)')

# %%
df_2019["Total"] = df_2019["Conteo Time"] + df_2019["Read Time"]
df_2019
# Out:
#         Test  Read Time  Conteo Time   Total
# 0   All file     131.67          6.6  138.27
# 1  Only date      25.50          1.3   26.80

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.barplot(y="Total",x="Test", data=df_2019, linewidth=2, saturation=4)
plt.title("TOTAL TIME - 2019", fontsize = 20)
plt.ylabel("Time (s)")
# Out:
# Text(0, 0.5, 'Time (s)')

# %%
df_c = {"Test": [1,2,3,4,5],
     "Read Time": [20.5,12.3,8.5,6.4,4.3]}
df_c = pd.DataFrame(data=df_c)
df_c
# Out:
#    Test  Read Time
# 0     1       20.5
# 1     2       12.3
# 2     3        8.5
# 3     4        6.4
# 4     5        4.3

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.barplot(y="Read Time",x="Test", data=df_c, linewidth=2, saturation=4)
plt.title("CLUSTERING TIME", fontsize = 20)
plt.ylabel("Time (s)")
# Out:
# Text(0, 0.5, 'Time (s)')
